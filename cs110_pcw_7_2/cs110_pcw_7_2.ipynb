# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Usama"
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # CS110 Pre-class Work 7.2
#
# ## Part A. Direct Address Tables
# As the first step in setting up a crossword solving algorithm you need to create 2 direct address tables, one to store all the “up” answers-whether correct or not-and one to store all the “across” answers. Write python code to create a direct address table that allows you to:
#
# 1. initialize N empty guesses
# 2. set a guess for the i-th entry
# 3. clear an incorrect guess for the i-th entry

# %%
table_1 = []
table_2 = []

def guess_table(size):  # Appends the tables with guesses
    for a in range (len(size)):
        table_1.append("")
        table_2.append("")
    
def vale_assignment(entry,value):  #Assigns value to each entry/guess
    table_1[entry] = value
    table_2[entry] = value
    
def clear_guess(entry):  #Clears the value of a particular entry
    table_1[entry] = ''
    table_2[entry] = ''

# %% [markdown]
# ## Part B. Social Security
#
# Could we use a direct address table to store a country's entire set of social security numbers (aka id numbers)? Why or why not?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Part C. Chained Hash-table
#
# ## Question 1.
#
# Using the code in the cell below, complete the missing sections of code. You should copy and paste the code in an additional cell and fill in the code there.

# %%
import random
import string


def randomword(length):
    return ''.join(random.choice(string.ascii_lowercase) for i in range(length))


def empty_hash_table(N):
    return [[] for n in range(N)]


def add_to_hash_table(hash_table, item, hash_function):
    N = len(hash_table)
    # Your code here
    return hash_table


def contains(hash_table, item, hash_function):
    N = len(hash_table)
    # Your code here
    # return true if the item has already been stored in the hash_table


def remove(hash_table, item, hash_function):
    if not contains(hash_table, item, hash_function):
        raise ValueError()
    # Your code here
    return hash_table


def hash_str1(string):
    ans = 0
    for chr in string:
        ans += ord(chr)
    return ans

# def hash_str2(string):
#     ans = 0
#     for chr in string:
#         ans = ans ^ ord(chr)
#     return ans
def hash_str2(string):
    ans=int(ord(string[0]))
    for ix in range(1, len(string)):
        ans = ans ^ ord(string[ix])   
    return bin(ans)


def hash_str3(string):
    ans = 0
    for chr in string:
        ans = ans * 128 + ord(chr)
    return ans


def hash_str4(string):
    random.seed(ord(string[0]))
    return random.getrandbits(32)

# %%
def add_to_hash_table(hash_table, item, hash_function):
    N = len(hash_table)
    if contains(hash_table, item, hash_function) == False:
        hash_table[hash_str1(string)].append(item)
        hash_table[hash_str2(string)].append(item)
        hash_table[hash_str3(string)].append(item)
        hash_table[hash_str4(string)].append(item) # items are appended into hash table at respected values   
    return hash_table

def contains(hash_table, item, hash_function):
    N = len(hash_table)
    if i in range(N):
        if i == hash_function:  # Looks if the value is in the array or not
            return True
        else:
            return False
    # return true if the item has already been stored in the hash_table
    
def remove(hash_table, item, hash_function):
    if not contains(hash_table, item, hash_function):
        raise ValueError()
    key  = hash_function(item) 
    hash_table[key] = []  #removes the value at this particular key
    return hash_table

# %% [markdown]
# ## Question 2.
# Using the code, create 100,000 words of 10 characters each.

# %%
words= [randomword(10) for n in range(100000)]
print (words)
# Out:
rcjz', 'izmlmypscy', 'zwgzqbvdqa', 'yzdyeiheri', 'zwlicpiwpj', 'rlsiggmkey', 'vqnkxxnvcn', 'sewnbrqevm', 'odiyryqnsn', 'wqqhtrnylf', 'vhqaldtrgc', 'gjegkjlflx', 'wnxbffgzyx', 'sceouxpnwv', 'hgcrtgdmbd', 'dhiscikqqh', 'ylofxaqloc', 'zbzivokdpp', 'mjuqhjfxsa', 'jrycgjknpt', 'tjgbpdqd ...

# %% [markdown]
# ## Question 3.
#
# Create four chained hash-tables with 5000 slots.

# %%
table_1=[[] for n in range(5000)]
table_2=[[] for n in range(5000)]
table_3=[[] for n in range(5000)]
table_4=[[] for n in range(5000)]

# %% [markdown]
# ## Question 4.
#
# Store all the words in each chained hash table using each of the different hash functions.

# %%
for i in words:
    add_to_hash_table(table_1,i, hash_str1(n))
    add_to_hash_table(table_2,i, hash_str2(n))
    add_to_hash_table(table_3,i, hash_str3(n))
    add_to_hash_table(table_4,i, hash_str4(n))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-431e11dc16db> in <module>()
#       1 for i in words:
# ----> 2     add_to_hash_table(table_1,i, hash_str1(n))
#       3     add_to_hash_table(table_2,i, hash_str2(n))
#       4     add_to_hash_table(table_3,i, hash_str3(n))
#       5     add_to_hash_table(table_4,i, hash_str4(n))
#
# NameError: name 'n' is not defined

# %% [markdown]
# ## Question 5.
#
# Measure the number of collisions for each hash function.

# %%
def count(table):
    counter = 0
    for i in range (len(words)):
        if words == 'iezhjtlexo':
            counter += 1
        else:
            counter += 0
    print (counter)
count(table_1)
count(table_2)
count(table_3)
count(table_4)
# Out:
# 0
# 0
# 0
# 0

# %% [markdown]
# ## Question 6.
#
# For each of the hash functions, how many elements are in a bucket on average (if it is not empty)?

# %%
def average(table):
    count=0
    counter=[]
    for i in range(len(table)):
        count+=1
    counter.append(count)
    sume=sum(counter)
    lenth=len(counter)
    average=sume/lenth
    return average
average(table_1)
average(table_2)
average(table_3)
average(table_4)
# Out:
# 5000.0

# %% [markdown]
# ## Question 7.
#
# Time how long it takes to find elements that are in each hash table.

# %%
import time

t_1 = time.time()
contains(table_1, 'abcdefghij', hash_str1(n)) 
t_2 = time.time()
print (t_2 - t_1)

t_3 = time.time()
contains(table_2, 'abcdefghij', hash_str2(n)) 
t_4 = time.time()
print (t_4 - t_3)

t_5 = time.time()
contains(table_3, 'abcdefghij', hash_str3(n)) 
t_6 = time.time()
print (t_6 - t_5)

t_7 = time.time()
contains(table_4, 'abcdefghij', hash_str3(n)) 
t_8 = time.time()
print (t_8 - t_7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-70b6147150f3> in <module>()
#       2
#       3 t_1 = time.time()
# ----> 4 contains(table_1, 'abcdefghij', hash_str1(n))
#       5 t_2 = time.time()
#       6 print (t_2 - t_1)
#
# NameError: name 'n' is not defined

# %% [markdown]
# ## Question 8.
# For each hash table, time how long it takes to find 10,000 elements that have not been stored.

# %%
# YOUR CODE HERE
raise NotImplementedError()
